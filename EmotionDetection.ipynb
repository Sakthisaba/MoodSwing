# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakthisaba/MoodSwing/blob/main/EmotionDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
                                                                                                                                                                                                                                                                                                                                                                                        arr=[]
for x in range(4):
  a = int(input("enter a Value"))
  arr.append(a)
  print(arr)

search = int(input("enter a Value to remove"))
k  =  0
for x in range(len(arr)-1) :
  
  if(arr[x]== search):
       arr.pop(x) 
      
  k= k+1
       
  
print(arr)
# Out:
# enter a Value1
# [1]
# enter a Value2
# [1, 2]
# enter a Value3
# [1, 2, 3]
# enter a Value4
# [1, 2, 3, 4]
# enter a Value to remove2
# [1, 3, 4]

# %%
from sklearn.cluster import DBSCAN

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("sample_data/california_housing_train.csv");

dbscan = DBSCAN(eps=0.5,min_samples=4)
data


x = data.loc[:, ['longitude',
                 'population']].values
dbscan.fit(x)
labels = dbscan.labels_ 
plt.scatter(x[:, 0], x[:,1], c = labels, cmap= "plasma")

 # plotting the clusters
plt.xlabel("Address") # X-axis label
plt.ylabel("Dense") # Y-axis label
plt.show() # showing the plot
x.shape
# Out:
# (17000, 2)

# %%
img = plt.imread('download.png')
plt.imshow(img)

# %%
from  sklearn.cluster import KMeans
color =4;

kmeans = KMeans(n_clusters=color)

# %%
arr=[]
for x in range(4):
  a = int(input("enter a Value"))
  arr.append(a)
  print(arr)

search = int(input("enter a Value to remove"))
k  =  0
for x in range(len(arr)-1) :
  
  if(arr[k]== search):
       print("Element found in")
      
  k= k+1

# %%
arr=[]
for x in range(4):
  a = int(input("enter a Value"))
  arr.append(a)

for i in range(len(arr)-1):
  for j in range(len(arr)-1):
   if(arr[j]>arr[j+1]):
     temp = arr[j+1]
     arr[j+1] = arr[j]
     arr[j] =temp
print(arr)
# Out:
# enter a Value30
# enter a Value1
# enter a Value8
# enter a Value3
# [1, 3, 8, 30]

# %%
arr=[]
for x in range(4):
  a = int(input("enter a Value"))
  arr.append(a)

for i in range(len(arr)-1):
  for j in range(len(arr)-1):
   if(arr[j]>arr[j+1]):
     temp = arr[j+1]
     arr[j+1] = arr[j]
     arr[j] =temp
print(arr)     
m = int(len(arr)/2)
print(m)
l=0;
h= len(arr)-1
search = int(input("enter a Value to remove"))
while h>=l:
  m = int(l+h/2)
  if arr[m] == search:
    print("found in ".format(arr[m])) 
  elif arr[m]<search:
     l=m+1;
  elif arr[m]>search:
     h=m-1;  
  else:
    print("not found")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# ### ***#NUMPY AND PANDAS***

# %%
import pandas as pd
import numpy as np


people_dict = { "weight": pd.Series([68, 83, 112],index=["alice", "bob", "charles"]),   "birthyear": pd.Series([1984, 1985, 1992], index=["bob", "alice", "charles"], name="year"),
"children": pd.Series([0, 3], index=["charles", "bob"]),
"hobby": pd.Series(["Biking", "Dancing"], index=["alice", "bob"]),}

pa =pd.DataFrame(
people_dict)
#pa[pa['birthyear']>=1980]

a = np.array([1,2,3,4,5,6])
dic = {
    "male":"yes",
    "job":"no"
}
a1  =(dic["job"]=="no") ? "ok selected":"rejected";
print(a[1:7])
# Out:
#   File "<ipython-input-16-1d3ea4a71e0d>", line 19
#     print(dic["job"]=="yes" ? "ok selected":"rejected")
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# <H1>**DATA SETS**</H1>

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("List of Orders.csv")

print(data)
data1 = data.dropna()

details = pd.read_csv("Order Details.csv")


data2 = details.dropna()


newdf = data1.merge(data2,on ='Order ID', how='inner')
print(newdf)
# Out:
#     Order ID  Order Date CustomerName           State       City
# 0    B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl     Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan  Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha       Rajasthan     Jaipur
# 4    B-25605  05-04-2018      Kasheen     West Bengal    Kolkata
# ..       ...         ...          ...             ...        ...
# 555      NaN         NaN          NaN             NaN        NaN
# 556      NaN         NaN          NaN             NaN        NaN
# 557      NaN         NaN          NaN             NaN        NaN
# 558      NaN         NaN          NaN             NaN        NaN
# 559      NaN         NaN          NaN             NaN        NaN
#
# [560 rows x 5 columns]

# %%
data1 = data.dropna()

details = pd.read_csv("Order Details.csv")


data2 = details.dropna()


newdf = data1.merge(data2,on ='Order ID', how='inner')
print(newdf)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
details = p("Order Details.csv")
sns.countplot(x='Order ID',data=details)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-409b85802ea8> in <module>()
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 details = pd.read_csv("Order Details.csv")
#       4 sns.countplot(x='Order ID',data=details)
#       5 plt.show()
#
# NameError: name 'pd' is not defined

# %%
from sklearn import pipeline
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
imdb = pd.read_csv("data.tsv",sep="\t")
SVM  =SVC()

Svmmodel = Pipeline(steps=[('classifier',SVM)])

train_x = imdb[:8000]
train_y = imdb[:1000]
train_x.drop(column='nco')
# Out:
#          nconst      primaryName birthYear deathYear  \
# 0     nm0000001     Fred Astaire      1899      1987
# 1     nm0000002    Lauren Bacall      1924      2014
# 2     nm0000003  Brigitte Bardot      1934        \N
# 3     nm0000004     John Belushi      1949      1982
# 4     nm0000005   Ingmar Bergman      1918      2007
# ...         ...              ...       ...       ...
# 7995  nm0008064       Tom Abbott        \N        \N
# 7996  nm0008065     Tommy Abbott      1934      1987
# 7997  nm0008066      Tony Abbott        \N        \N
# 7998  nm0008067    Tracey Abbott        \N        \N
# 7999  nm0008068       Vic Abbott        \N        \N
#
#                         primaryProfession  \
# 0          soundtrack,actor,miscellaneous
# 1                      actress,soundtrack
# 2     actress,soundtrack,music_department
# 3                 actor,soundtrack,writer
# 4                   writer,director,actor
# ...                                   ...
# ...

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
data = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
X = data.iloc[:,3:-1].values
Y = data.iloc[:,-1].values
from sklearn.preprocessing import LabelEncoder
LE1 = LabelEncoder()
X[:,2] = np.array(LE1.fit_transform(X[:,2]))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct =ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[1])],remainder="passthrough")
X = np.array(ct.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-164cc17c6825> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# ...

# %%
pip install deepface

# %%
from  deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/images.jpg")

img = cv2.resize(img,(500,500))
plt.imshow(img[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img,actions = ['age', 'gender', 'race', 'emotion'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-39-9bc9ca1fdaf1> in <module>()
# ----> 1 result = DeepFace.analyze(img,actions = ['age', 'gender', 'race', 'emotion'])
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     358
#     359         if 'race' in actions and 'race' not in built_models:
# --> 360                 models['race'] = build_model('Race')
#     361
#     362         #---------------------------------
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in build_model(model_name)
#      61                 model = models.get(model_name)
#      62                 if model:
# ---> 63                         model = model()
#      64                         model_obj[model_name] = model
# ...

# %%
embedding = DeepFace.represent(img_path = "/content/images.jpg", model_name = 'Facenet')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-f0aeb529a118> in <module>()
# ----> 1 embedding = DeepFace.represent(img_path = "/content/images.jpg", model_name = 'Facenet')
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in represent(img_path, model_name, model, enforce_detection, detector_backend, align, normalization)
#     756                 , enforce_detection = enforce_detection
#     757                 , detector_backend = detector_backend
# --> 758 		, align = align)
#     759
#     760         #---------------------------------
#
# /usr/local/lib/python3.7/dist-packages/deepface/commons/functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
#     176         base_img = img.copy()
#     177
# ...
